# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Data_analytics/gender_submission.csv')
df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df=pd.read_csv('/content/drive/MyDrive/Data_analytics/test.csv')
df
# Out:
#      PassengerId  Pclass  ... Cabin Embarked
# 0            892       3  ...   NaN        Q
# 1            893       3  ...   NaN        S
# 2            894       2  ...   NaN        Q
# 3            895       3  ...   NaN        S
# 4            896       3  ...   NaN        S
# ..           ...     ...  ...   ...      ...
# 413         1305       3  ...   NaN        S
# 414         1306       1  ...  C105        C
# 415         1307       3  ...   NaN        S
# 416         1308       3  ...   NaN        S
# 417         1309       3  ...   NaN        C
#
# [418 rows x 11 columns]

# %%
df=pd.read_csv('/content/drive/MyDrive/Data_analytics/test.csv')
df.dropna()
df
# Out:
#      PassengerId  Pclass  ... Cabin Embarked
# 0            892       3  ...   NaN        Q
# 1            893       3  ...   NaN        S
# 2            894       2  ...   NaN        Q
# 3            895       3  ...   NaN        S
# 4            896       3  ...   NaN        S
# ..           ...     ...  ...   ...      ...
# 413         1305       3  ...   NaN        S
# 414         1306       1  ...  C105        C
# 415         1307       3  ...   NaN        S
# 416         1308       3  ...   NaN        S
# 417         1309       3  ...   NaN        C
#
# [418 rows x 11 columns]

# %%
df=pd.read_csv('/content/drive/MyDrive/Data_analytics/train.csv')
df.drop('PassengerId',axis=1,inplace=True)
df.drop('Name',axis=1,inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  ...            Ticket     Fare Cabin  Embarked
# 0           0       3    male  22.0  ...         A/5 21171   7.2500   NaN         S
# 1           1       1  female  38.0  ...          PC 17599  71.2833   C85         C
# 2           1       3  female  26.0  ...  STON/O2. 3101282   7.9250   NaN         S
# 3           1       1  female  35.0  ...            113803  53.1000  C123         S
# 4           0       3    male  35.0  ...            373450   8.0500   NaN         S
# ..        ...     ...     ...   ...  ...               ...      ...   ...       ...
# 886         0       2    male  27.0  ...            211536  13.0000   NaN         S
# 887         1       1  female  19.0  ...            112053  30.0000   B42         S
# 888         0       3  female   NaN  ...        W./C. 6607  23.4500   NaN         S
# 889         1       1    male  26.0  ...            111369  30.0000  C148         C
# ...

# %%
f=pd.read_csv('/content/drive/MyDrive/Data_analytics/train.csv')
g=f.Fare
plt.hist()
plt.show()

# %%
j=f.Fare
plt.hist(j)
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <a list of 10 Patch objects>)

# %%
total=len(f.index)
rows=round(0.8*total)
print(f.iloc[0:rows])
print(f.iloc[rows+1:total])
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0              1         0       3  ...    7.2500   NaN         S
# 1              2         1       1  ...   71.2833   C85         C
# 2              3         1       3  ...    7.9250   NaN         S
# 3              4         1       1  ...   53.1000  C123         S
# 4              5         0       3  ...    8.0500   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 708          709         1       1  ...  151.5500   NaN         S
# 709          710         1       3  ...   15.2458   NaN         C
# 710          711         1       1  ...   49.5042   C90         C
# 711          712         0       1  ...   26.5500  C124         S
# 712          713         1       1  ...   52.0000  C126         S
#
# [713 rows x 12 columns]
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 714          715         0       2  ...   13.000    NaN         S
# ...
